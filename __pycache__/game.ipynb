# %%
# Домашнее задание: Игра "Угадай число"

# %%
import game
# Out:
# Число должно быть больше!
# Число должно быть больше!
# Число должно быть больше!
# Число должно быть меньше!
# Число должно быть меньше!
# Число должно быть меньше!
# Вы угадали число! Это число = 60, за 7 попыток

# %%
import game_v2
game_v2.score_game(game_v2.random_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 101 попыток
# 101

# %% [markdown]
# # Игра "Угадай число"

# %% [markdown]
# ## Угадываем рандомно
# ### Импортируем функции

# %%
from game_v2 import score_game
from game_v2 import random_predict

# %% [markdown]
# ### Запускаем оценку алгоритма

# %%
score_game(random_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 101 попыток
# 101

# %% [markdown]
# ### Выводы
# Алгоритм угадывает число в среднем за **101 попытку**.
# Это нормальный результат для случайного угадывания.
